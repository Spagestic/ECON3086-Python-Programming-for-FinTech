# %% [markdown]
# # Exercise 9a - Basic operations with dataframe

# %% [markdown]
# Using the yfinance library to get Microsoft Stock data of past 5 years.

# %%
import pandas as pd
import yfinance as yf

# Get MSFT stock data for the last 5 years using history method
msft_ticker = yf.Ticker('MSFT')
msft = msft_ticker.history(period="5y")

# %%
msft
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-25 00:00:00-04:00  225.784364  227.358041  222.205211  222.944061
# 2021-03-26 00:00:00-04:00  222.186020  227.137350  222.186020  226.916641
# 2021-03-29 00:00:00-04:00  227.022219  227.223733  222.502701  225.726822
# 2021-03-30 00:00:00-04:00  224.085945  224.393011  221.754223  222.473892
# 2021-03-31 00:00:00-04:00  223.491071  229.430748  222.992096  226.235413
# ...                               ...         ...         ...         ...
# 2026-03-18 00:00:00-04:00  397.130005  398.000000  391.000000  391.790009
# 2026-03-19 00:00:00-04:00  390.100006  392.489990  387.059998  389.019989
# 2026-03-20 00:00:00-04:00  386.790009  387.000000  380.119995  381.869995
# 2026-03-23 00:00:00-04:00  383.899994  387.209991  381.679993  383.000000
# 2026-03-24 00:00:00-04:00  382.410004  382.470001  371.850006  372.739990
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# Q1. List the Index

# %%
msft.index
# Out:
# DatetimeIndex(['2021-03-25 00:00:00-04:00', '2021-03-26 00:00:00-04:00',
#                '2021-03-29 00:00:00-04:00', '2021-03-30 00:00:00-04:00',
#                '2021-03-31 00:00:00-04:00', '2021-04-01 00:00:00-04:00',
#                '2021-04-05 00:00:00-04:00', '2021-04-06 00:00:00-04:00',
#                '2021-04-07 00:00:00-04:00', '2021-04-08 00:00:00-04:00',
#                ...
#                '2026-03-11 00:00:00-04:00', '2026-03-12 00:00:00-04:00',
#                '2026-03-13 00:00:00-04:00', '2026-03-16 00:00:00-04:00',
#                '2026-03-17 00:00:00-04:00', '2026-03-18 00:00:00-04:00',
#                '2026-03-19 00:00:00-04:00', '2026-03-20 00:00:00-04:00',
#                '2026-03-23 00:00:00-04:00', '2026-03-24 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=1255, freq=None)

# %% [markdown]
# Q2. List the Columns Name

# %%
msft.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %% [markdown]
# Q3. Filter the dataframe to get the data of 2024 only.

# %%
msft_2024 = msft.loc['2024']
msft_2024
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00-05:00  367.528834  369.534296  360.558903  364.589478
# 2024-01-03 00:00:00-05:00  362.760996  366.939024  362.269463  364.324066
# 2024-01-04 00:00:00-05:00  364.392855  366.781697  360.952126  361.709076
# 2024-01-05 00:00:00-05:00  362.721649  365.759318  360.293477  361.522308
# 2024-01-08 00:00:00-05:00  363.046020  368.846130  362.760953  368.344757
# ...                               ...         ...         ...         ...
# 2024-12-24 00:00:00-05:00  430.484578  435.387152  430.028995  435.119720
# 2024-12-26 00:00:00-05:00  434.872143  436.714334  432.445641  433.911438
# 2024-12-27 00:00:00-05:00  430.435086  431.049140  422.264149  426.404083
# 2024-12-30 00:00:00-05:00  421.976951  423.452663  417.856814  420.758728
# 2024-12-31 00:00:00-05:00  422.016555  422.640522  416.628686  417.460632
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# Q4 Filter the dataframe to get the data of Mar 2023.

# %%
msft_mar_2023 = msft.loc['2023-03']
msft_mar_2023
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-03-01 00:00:00-05:00  244.958888  245.124953  240.103863  240.572769
# 2023-03-02 00:00:00-05:00  240.846290  245.584081  239.928034  245.300797
# 2023-03-03 00:00:00-05:00  246.355804  249.706447  245.574308  249.384079
# 2023-03-06 00:00:00-05:00  250.497697  254.102335  250.058111  250.927521
# 2023-03-07 00:00:00-05:00  250.370702  251.728560  247.528034  248.270447
# 2023-03-08 00:00:00-05:00  248.163018  248.651451  245.007745  247.830887
# 2023-03-09 00:00:00-05:00  249.901849  253.555318  245.759932  246.482819
# 2023-03-10 00:00:00-05:00  245.271451  246.941883  241.871963  242.839050
# 2023-03-13 00:00:00-04:00  241.676622  251.943492  240.045257  248.045792
# 2023-03-14 00:00:00-04:00  250.810335  255.030403  249.940925  254.756882
# 2023-03-15 00:00:00-04:00  253.965606  260.315235  253.213401  259.299286
# 2023-03-16 00:00:00-04:00  259.074617  270.162052  257.189273  269.810394
# ...

# %% [markdown]
# Q5.
# - Create a new column "Intraday Price Change" where the value is Close price - Open price
# - Create a new column "Price Change" where the value is Close price - last trading day Close price
# - Create a new column "Percentage change" where the value is close price / last trading day close price - 1

# %%
msft['Intraday Price Change'] = msft['Close'] - msft['Open']
msft['Price Change'] = msft['Close'] - msft['Close'].shift(1)
msft['Percentage change'] = msft['Close'] / msft['Close'].shift(1) - 1

msft
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-25 00:00:00-04:00  225.784364  227.358041  222.205211  222.944061
# 2021-03-26 00:00:00-04:00  222.186020  227.137350  222.186020  226.916641
# 2021-03-29 00:00:00-04:00  227.022219  227.223733  222.502701  225.726822
# 2021-03-30 00:00:00-04:00  224.085945  224.393011  221.754223  222.473892
# 2021-03-31 00:00:00-04:00  223.491071  229.430748  222.992096  226.235413
# ...                               ...         ...         ...         ...
# 2026-03-18 00:00:00-04:00  397.130005  398.000000  391.000000  391.790009
# 2026-03-19 00:00:00-04:00  390.100006  392.489990  387.059998  389.019989
# 2026-03-20 00:00:00-04:00  386.790009  387.000000  380.119995  381.869995
# 2026-03-23 00:00:00-04:00  383.899994  387.209991  381.679993  383.000000
# 2026-03-24 00:00:00-04:00  382.410004  382.470001  371.850006  372.739990
#
#                              Volume  Dividends  Stock Splits  \
# Date
# ...

# %% [markdown]
# Q6. Check whether there were any dividend within the data

# %%
has_dividend = (msft['Dividends'] > 0).any()
has_dividend
# Out:
# np.True_

# %% [markdown]
# Q7. Remove the column "Dividends" from the dataframe

# %%
msft = msft.drop(columns=['Dividends'])
msft
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-25 00:00:00-04:00  225.784364  227.358041  222.205211  222.944061
# 2021-03-26 00:00:00-04:00  222.186020  227.137350  222.186020  226.916641
# 2021-03-29 00:00:00-04:00  227.022219  227.223733  222.502701  225.726822
# 2021-03-30 00:00:00-04:00  224.085945  224.393011  221.754223  222.473892
# 2021-03-31 00:00:00-04:00  223.491071  229.430748  222.992096  226.235413
# ...                               ...         ...         ...         ...
# 2026-03-18 00:00:00-04:00  397.130005  398.000000  391.000000  391.790009
# 2026-03-19 00:00:00-04:00  390.100006  392.489990  387.059998  389.019989
# 2026-03-20 00:00:00-04:00  386.790009  387.000000  380.119995  381.869995
# 2026-03-23 00:00:00-04:00  383.899994  387.209991  381.679993  383.000000
# 2026-03-24 00:00:00-04:00  382.410004  382.470001  371.850006  372.739990
#
# ...

# %% [markdown]
# Q8. Find the highest stock price ever in this period, and find the date of it

# %%
highest_price = msft['High'].max()
highest_price_date = msft['High'].idxmax()

highest_price, highest_price_date
# Out:
# (np.float64(552.2420017670738),
#  Timestamp('2025-07-31 00:00:00-0400', tz='America/New_York'))

# %% [markdown]
# Q9. Find the highest volume date

# %%
highest_volume = msft['Volume'].max()
highest_volume_date = msft['Volume'].idxmax()

highest_volume_date, highest_volume
# Out:
# (Timestamp('2026-01-29 00:00:00-0500', tz='America/New_York'),
#  np.int64(128855300))

# %% [markdown]
# Q10. Find the top 20 highest price percentage change date and it's percentage change, order in decending order.

# %%
highest_volume = msft['Volume'].max()
highest_volume_date = msft['Volume'].idxmax()

highest_volume_date, highest_volume
# Out:
# (Timestamp('2026-01-29 00:00:00-0500', tz='America/New_York'),
#  np.int64(128855300))
